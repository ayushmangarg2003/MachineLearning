# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushmangarg2003/ml/blob/main/multivariate_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/SharkTankIndiaDataset.csv')
df.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %% [markdown]
# # Scatter Plot (Numerical - Numerical)

# %%
sns.scatterplot(x=df['ask_equity'], y=df['deal_equity'],hue=df['peyush_deal'],style=df['aman_deal'],size=df['ask_valuation'])
# Out:
# <Axes: xlabel='ask_equity', ylabel='deal_equity'>

# %% [markdown]
# # Bar Plot (Numerical - Categorical)

# %%
sns.barplot(x=df['total_sharks_invested'],y=df['deal_amount'],hue=df['aman_deal'])
# Out:
# <Axes: xlabel='total_sharks_invested', ylabel='deal_amount'>

# %% [markdown]
# # Box Plot (Numerical - Categorical)

# %%
sns.boxplot(x=df['total_sharks_invested'],y=df['deal_amount'])
# Out:
# <Axes: xlabel='total_sharks_invested', ylabel='deal_amount'>

# %% [markdown]
# # Heat Map (Categorical - Categorical)

# %%
 sns.heatmap(pd.crosstab(df['total_sharks_invested'],df['aman_deal']))
# Out:
# <Axes: xlabel='aman_deal', ylabel='total_sharks_invested'>

# %% [markdown]
# # Cluster map (Categorical - Categorical)

# %%
 sns.clustermap(pd.crosstab(df['total_sharks_invested'],df['aman_deal']))

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df)
